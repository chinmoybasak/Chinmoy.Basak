# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmoybasak/Chinmoy.Basak/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
 
from urllib.request import urlopen
# Out:
#      <input type="file" id="files-735b457c-16b5-497a-9cd8-1e22811fd675" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-735b457c-16b5-497a-9cd8-1e22811fd675">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.txt to Test.txt

# %%
cd /content/
# Out:
# /content

# %%
import re
import pandas as pd
from io import StringIO
with open('Test.txt','r') as f:
    p = f.read()
print(p)
df12, df22= [], []
 
for l in p.splitlines():
    x=p.count('>')
    df12.append(x)
    # x, y= re.split(r">+", l)
    # df12.append(x.split("."))
    # df22.append(y.split("."))
print(pd.DataFrame(df12))
print(pd.DataFrame(df22))
# Out:
# [Na+].[CH3:2][C:3](=[O:5])[O-].[CH3:6][c:7]1[cH:12][cH:11][cH:10][cH:9][cH:8]1>>[c:7]1([CH3:6])[c:12]([C:3]([c:2]2[cH:11][cH:12][cH:7][cH:8][c:9]2[CH3:10])=[O:5])[cH:11][cH:10][cH:9][cH:8]1
# [CH:1]1([C:4]([c:6]2[cH:11][cH:10][c:9]([C:12]([CH3:20])(C)[C:13](N(C)OC)=O)[cH:8][cH:7]2)=[O:5])[CH2:3][CH2:2]1.[BrH:21].[C:22](=[O:25])([O-])[OH:23].[Na+]>O>[Br:21][CH2:3][CH2:2][CH2:1][C:4]([c:6]1[cH:11][cH:10][c:9]([C:12]([CH3:20])([CH3:13])[C:22]([OH:23])=[O:25])[cH:8][cH:7]1)=[O:5]
# [Na+].[CH3:2][C:3](=[O:5])[O-:4].[C:6]([O-:14])(=[O:13])[c:7]1[cH:12][cH:11][cH:10][cH:9][cH:8]1.[Na+]>CN1CCCC1=O>[C:3]([O:4][CH2:8][C:7](=[CH2:6])[CH3:12])(=[O:5])[CH3:2].[O-:14][C:6]([c:7]1[cH:12][cH:11][cH:10][cH:9][cH:8]1)=[O:13]
# [C:1]([O:4][CH2:5][C:6](=[CH2:8])[CH3:7])(=[O:3])[CH3:2].[Cl-].[Al+3].[Cl-].[Cl-].[cH:13]1[cH:18][cH:17][cH:16][cH:15][cH:14]1>>[C:1]([O:4][CH2:5][C:6]([c:13]1[cH:18][cH:17][cH:16][cH:15][cH:14]1)([CH3:7])[CH3:8])(=[O:3])[CH3:2]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io
df2 = pd.read_csv(io.BytesIO(uploaded['6-3-13_MR5658_RES_1.csv']),sep=",", encoding='ISO 8859-1',header=None, error_bad_lines=False)
 
def CIRconvert(ids):
    try:
        url = 'http://cactus.nci.nih.gov/chemical/structure/' + ids + '/smiles'
        ans = urlopen(url).read().decode('utf8')
        return ans
    except:
        return 'Did not work'
 
df2[[32, 33]] = df2[13].str.extract(r"([A-Za-z\s]+)([\d\-]+)")
identifiers = df2[33]
NID=[len(df2)]
print(identifiers)
df234=[]
for ids in identifiers :
    df234.append(CIRconvert(ids))
df2[34]=df234
print(df234)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-af5fe017cb12> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 import io
# ----> 4 df2 = pd.read_csv(io.BytesIO(uploaded['6-3-13_MR5658_RES_1.csv']),sep=",", encoding='ISO 8859-1',header=None, error_bad_lines=False)
#       5
#       6 # def CIRconvert(ids):
#
# KeyError: '6-3-13_MR5658_RES_1.csv'

# %%
df2= df2.dropna(subset=[33])

# %%
df2
# Out:
#                                          0   ...            34
# 2                  VALERO REFINING COMPANY   ...             S
# 7                        Vulcan Chemicals    ...         ClCCl
# 8                        Rich-Sea Pak Corp   ...             N
# 9           Department of Water and Power    ...          ClCl
# 15                       Nuex Exploration    ...  Did not work
# ...                                     ...  ...           ...
# 8017  Apache Corporation, Gulf Coast Region  ...  Did not work
# 8018                          FPL Food, LLC  ...             N
# 8020        Amsted Steel - Granite City, IL  ...             C
# 8023                West Fertilizer Company  ...             N
# 8025                       Foss Swim School  ...          ClCl
#
# [1504 rows x 35 columns]
